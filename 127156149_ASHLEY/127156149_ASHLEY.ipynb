# %%
seen={}
def get(key):
    return seen[key]
    


def put(arr,c):
    
    for i in range(len(arr)):
        if i<c:
            seen[i]=arr[i]
        else:
            print('The capacity of this is over')
            break
        
if __name__=='__main__':
    capacity=int(input())
    q=int(input())
    arr=[]
    for x in range(q):
        y=int(input('enter value to be inserted'))
        arr.append(y)
    put(arr,capacity)
    k=print('do you want to get value?? YES/NO')
    k=input()
    if k=='YES':
        KEY=len(arr)
        value=get(key)
        print(value)
    else:
        pass
# Out:
#  4
#  5
# enter value to be inserted 1
# enter value to be inserted 2
# enter value to be inserted 3
# enter value to be inserted 4
# enter value to be inserted 5
# The capacity of this is over
# do you want to get value?? YES/NO
#  YES
# 2
